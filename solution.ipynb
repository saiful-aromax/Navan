# %%
##IMPORTING LIBRARIES
import pandas as pd
import statistics as stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# IMPORTING DATASET
# Importing the dataset
dataset = pd.read_csv(
    "C:\\Users\\aromax\\Documents\\AroProjects\\Navan\\garments_worker_productivity.csv"
)
dataset.head()
# Out:
#   department       day  team  targeted_productivity    smv   wip  over_time  \
# 0     sweing  Thursday     8                    0.8  26.16  1108       7080
# 1     sweing  Thursday    11                    0.8  11.41   968       3660
# 2     sweing  Thursday    12                    0.8  11.41   968       3660
# 3     sweing  Thursday     6                    0.8  25.90  1170       1920
# 4     sweing  Thursday     7                    0.8  25.90   984       6720
#
#    incentive  idle_time  idle_men  no_of_style_change  no_of_workers  \
# 0         98        0.0         0                   0           59.0
# 1         50        0.0         0                   0           30.5
# 2         50        0.0         0                   0           30.5
# 3         50        0.0         0                   0           56.0
# 4         38        0.0         0                   0           56.0
#
#    actual_productivity
# 0             0.940725
# 1             0.800570
# ...

# %%
sns.lmplot(x='incentive', y='actual_productivity', data=dataset, ci=None)

plt.xlabel('Incentive')
plt.ylabel('Actual Productivity')
plt.title('Scatter Plot for Incentive vs Actual Productivity')

# Display the plot
plt.show()
# Out:
# c:\Users\aromax\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Pairplot

sns.pairplot(dataset)

# %% [markdown]
# After analyzing, it can be observed that the following variables has influences over Employee's performance:
# 1. targeted_productivity
# 2. smv
# 3. wip
# 4. over_time
# 5. incentive
# 6. idle_time
# 7. idle_men
# 8. no_of_workers

# %%
X = dataset[["targeted_productivity", "smv", "wip", "over_time", "incentive", "idle_time", "idle_men", "no_of_workers"]]
y = dataset["actual_productivity"]

# %%
# We need to split the data into training and testing set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=0
)

# %%
# We train the model for Linear Regression

from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
# We calculate the accuracy of this model (r^2)

regressor.score(X_train, y_train)
# Out:
# 0.8112921705293095

# %% [markdown]
# As r^2 is 0.92 we can say that 92% of the changes in the tv sales will depend on the ads that are placed in the TV and the Newspapers.

# %%
# We can make predictions

print(regressor.predict([[0.59, 29.34, 940, 6530, 27, 0, 0, 52]]))
# Out:
# [0.57382564]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Example DataFrame
data = {
    'Variable1': np.random.rand(100),
    'Variable2': np.random.rand(100)
}
df = pd.DataFrame(data)

# Scatter plot with line of best fit
sns.lmplot(x='Variable1', y='Variable2', data=df, ci=None)

plt.xlabel('Variable 1')
plt.ylabel('Variable 2')
plt.title('Scatter Plot with Line of Best Fit')

# Display the plot
plt.show()
# Out:
# c:\Users\aromax\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
